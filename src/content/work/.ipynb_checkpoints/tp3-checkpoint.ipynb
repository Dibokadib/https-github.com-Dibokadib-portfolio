# %%
from fenics import *
import pylab as plt
import matplotlib.pyplot as plt
from create_mesh import create_mesh
# %matplotlib inline

i = -1
err = []
j = []

for nu in [0.3, 0.48, 0.4999]:
    for n in [2, 4, 8, 16, 32, 64]:
        i = i + 1
        j.append(n)
        # Scaled variables
        a = 1.
        b = 4.*a
        w = b
        E = 1.
        t = 1.
        lmbda = E*nu/((1.+nu)*(1.-2.*nu))
        mu = E/(2.*(1.+nu))
        # CP
        k = 3.-4.*nu
        # DP
        #k = (3.-nu)/(1.+nu)
        
        
        # Define strain and stress
        def eps(u):
            return sym(grad(u))
        
        def sigma(u,lmbda,mu):
            e = eps(u)
            return lmbda*tr(e)*Identity(2) + 2.*mu*e
        
        
        # Define variational problem
        mesh, boundaries = create_mesh(n,a,b,w)
        element = VectorElement('P', triangle, 1)
        V = FunctionSpace(mesh, element)
        u = TrialFunction(V)
        v = TestFunction(V)
        T = Constant((0., 0.))
        f = Constant((0., 0.))
        ds = Measure('ds', domain=mesh, subdomain_data=boundaries)
        
        u_ = TrialFunction(V)
        a_form = inner(sigma(u_,lmbda,mu), eps(v))*dx
        L_form = dot(T,v)*ds(2) + dot(f,v)*dx
        
        # Define a complex expression: Exact solution for a plate with hole
        #!python
        def exact_solution(a,mu,k):
            r = Expression("sqrt(pow(x[0],2)+pow(x[1],2))")
            theta = Expression("atan2(x[1],x[0])")
            u_ex = Expression(
                ("(t*a)/(8*G)*((r/a)*(k+1)*cos(theta)+2*a/r*((1+k)*cos(theta)+cos(3*theta))-2*pow(a/r,3)*cos(3*theta))",
                 "(t*a)/(8*G)*((r/a)*(k-3)*sin(theta)+2*a/r*((1-k)*sin(theta)+sin(3*theta))-2*pow(a/r,3)*sin(3*theta))"),
                a=a,G=mu,r=r,theta=theta,k=k,t=t,degree=3)
            return u_ex
        uex = exact_solution(a,mu,k)
        
        
        def boundary(x, on_boundary):
            return on_boundary
        
        bc = DirichletBC(V,uex,boundary)
        
        # Compute solution
        u = Function(V)
        solve(a_form == L_form, u, bc)
        
        
        # Compute error in L2 norm
        err.append(errornorm(uex,u,'L2')*100.)
        #normex = errornorm(uex,Function(W.sub(0)),'L2')
        print(err)
# Out:
# [15.58596863273299]
# [15.58596863273299, 12.895929568783405]
# [15.58596863273299, 12.895929568783405, 8.00764273363286]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003, 62.90763441177197]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003, 62.90763441177197, 136.5594268644991]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003, 62.90763441177197, 136.5594268644991, 90.21884439398792]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003, 62.90763441177197, 136.5594268644991, 90.21884439398792, 83.7914049012273]
# [15.58596863273299, 12.895929568783405, 8.00764273363286, 8.883742914743792, 9.359673925596672, 9.613395795846403, 30.684816973053795, 41.6972818902574, 51.041135931551885, 47.89529942961023, 47.227733997292795, 47.12036388656307, 39.17858277892003, 62.90763441177197, 136.5594268644991, 90.21884439398792, 83.7914049012273, 65.95747071098094]

# %%
plt.figure(1)
plt.loglog(j[0:5],err[0:5],basex=10,basey=10,label='0.3')
plt.loglog(j[0:5],err[6:11],basex=10,basey=10,label='0.48')
plt.loglog(j[0:5],err[12:17],basex=10,basey=10,label='0.4999')
plt.legend(loc=3)
plt.xlabel('taille du maillage')
plt.ylabel('erreur %')
plt.title('convergence de l erreur')
plt.savefig('fig2.png')
plt.show()

# %%
plot(interpolate(uex,V),mode='displacement',title='exacte')

# %%
plot(interpolate(u,V),mode='displacement',title='numerique')

# %%
# Compute error in L2 norm
error_L2 = errornorm(uex,u,'L2')
print(error_L2*100.)
# Out:
# 1.06687006233

# %%
mesh.hmax()
# Out:
# 0.564868943222945
